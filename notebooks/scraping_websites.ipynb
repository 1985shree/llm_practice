# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# # with beautifulsoup

# %%
# fetch HTML content from a URL
url = 'https://www.confident-group.com/blog/old-parents-only-houses-is-increasing-in-kottayam/'
response = requests.get(url)
html_content = response.text

# extract text from the HTML content
soup = BeautifulSoup(html_content, 'html.parser')
text = soup.get_text()

# print the extracted text
print(text)
# Out:
# No. of 'old parents only' houses is increasing in Kottayam | Confident Group
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Kerala : +91-9895904444
# Bangalore : +91-7406546000
# Dubai : +971-553387577
#
#
#  [email protected]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
# About
#
#
# Chairman’s Message
# Group of Companies
# Team Kerala
# Events
# News
# Careers
# Key Handing Over
# Testimonials
# Helping Hand
# Prarthana Cancer Care
# City Highlights
#
#
#
#
# Kerala
#
#
# Kochi
#
# Kakkanad
#
#
# Trivandrum
#
# Technopark
#
#
# Thrissur
# Kottayam
# Calicut
#
#
#
#
# Bangalore
#
#
# Residential
# Commercial
# Hospitality
#
# Natures Luxuri
# Confident Sarjapur Hotel
#
#
# Golf
#
# Zion Hills
#
#
# Entertainment
# Education
#
# Confident Gear Foundation School
# Confident Gear Sarjapur
#
#
#
#
#
# Lifestyle Plus
#
#
# Confi Luxe
#
#
# Smile Homes
#
#
# Contact Us
#
#
#
#
#
# Search
#
#
#
#
# ...

# %% [markdown]
# # with selenium driver + beautifulsoup

# %%
# set up a headless Chrome browser
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome(options=options)

# navigate to a URL and get its HTML content
url = 'https://www.confident-group.com/blog/old-parents-only-houses-is-increasing-in-kottayam/'
driver.get(url)
html_content = driver.page_source

# extract text from the HTML content
soup = BeautifulSoup(html_content, 'html.parser')
text = soup.get_text()

# print the extracted text
print(text)

# close the browser
driver.quit()
# Out:
# No. of 'old parents only' houses is increasing in Kottayam | Confident Group
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Kerala : +91-9895904444
# Bangalore : +91-7406546000
# Dubai : +971-553387577
#
#
#  sales@confident-group.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
# About
#
#
# Chairman’s Message
# Group of Companies
# Team Kerala
# Events
# News
# Careers
# Key Handing Over
# Testimonials
# Helping Hand
# Prarthana Cancer Care
# City Highlights
#
#
#
#
# Kerala
#
#
# Kochi
#
# Kakkanad
#
#
# Trivandrum
#
# Technopark
#
#
# Thrissur
# Kottayam
# Calicut
#
#
#
#
# Bangalore
#
#
# Residential
# Commercial
# Hospitality
#
# Natures Luxuri
# Confident Sarjapur Hotel
#
#
# Golf
#
# Zion Hills
#
#
# Entertainment
# Education
#
# Confident Gear Foundation School
# Confident Gear Sarjapur
#
#
#
#
#
# Lifestyle Plus
#
#
# Confi Luxe
#
#
# Smile Homes
#
#
# Contact Us
#
#
#
#
#
# Search
# ...

# %%
print(text)
